# %%
Χαρακτηριστικα, τιμες χαρακτηριστικων, συχνοτητες χαρακτηριστικων και γραφικη αναπαρασταση (ο,τι ειδους θες)
column, possible values, frequency of values
id, int, 
gender, [Male,Female,Other], 
age, int
hypertension, [0,1]
heart_disease, [0,1]
ever_married, ["Yes", "No"]
work_type, ["children", "Govt_jov", "Never_worked", "Private","Self-employed"]
Residence_type, ["Rural","Urban"]
avg_glucose_level, int
bmi, int
smoking_status, ["formerly smoked", "never smoked", "smokes", "unknown"]
stroke, [0,1]

# %%
import pandas as pd
import matplotlib.pyplot as plt
csv = pd.read_csv("healthcare-dataset-stroke-data\healthcare-dataset-stroke-data.csv")
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
ids = csv["id"]
ids.plot()
ids.unique()
# Out:
# array([ 9046, 51676, 31112, ..., 19723, 37544, 44679], dtype=int64)

# %%
gender = csv["gender"]
gender.value_counts().plot.bar()
gender.unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
age = csv["age"]
age.value_counts()
# Out:
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 0.48       3
# 1.40       3
# 0.16       3
# 0.08       2
# 0.40       2
# Name: age, Length: 104, dtype: int64

# %%
age.unique()
# Out:
# array([6.70e+01, 6.10e+01, 8.00e+01, 4.90e+01, 7.90e+01, 8.10e+01,
#        7.40e+01, 6.90e+01, 5.90e+01, 7.80e+01, 5.40e+01, 5.00e+01,
#        6.40e+01, 7.50e+01, 6.00e+01, 5.70e+01, 7.10e+01, 5.20e+01,
#        8.20e+01, 6.50e+01, 5.80e+01, 4.20e+01, 4.80e+01, 7.20e+01,
#        6.30e+01, 7.60e+01, 3.90e+01, 7.70e+01, 7.30e+01, 5.60e+01,
#        4.50e+01, 7.00e+01, 6.60e+01, 5.10e+01, 4.30e+01, 6.80e+01,
#        4.70e+01, 5.30e+01, 3.80e+01, 5.50e+01, 1.32e+00, 4.60e+01,
#        3.20e+01, 1.40e+01, 3.00e+00, 8.00e+00, 3.70e+01, 4.00e+01,
#        3.50e+01, 2.00e+01, 4.40e+01, 2.50e+01, 2.70e+01, 2.30e+01,
#        1.70e+01, 1.30e+01, 4.00e+00, 1.60e+01, 2.20e+01, 3.00e+01,
#        2.90e+01, 1.10e+01, 2.10e+01, 1.80e+01, 3.30e+01, 2.40e+01,
#        3.40e+01, 3.60e+01, 6.40e-01, 4.10e+01, 8.80e-01, 5.00e+00,
#        2.60e+01, 3.10e+01, 7.00e+00, 1.20e+01, 6.20e+01, 2.00e+00,
#        9.00e+00, 1.50e+01, 2.80e+01, 1.00e+01, 1.80e+00, 3.20e-01,
# ...

# %%
hypertension = csv["hypertension"]
hypertension.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
heart_disease = csv["heart_disease"]
heart_disease.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ever_married = csv["ever_married"]
ever_married.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
work_type = csv["work_type"]
work_type.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
Residence_type = csv["Residence_type"]
Residence_type.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
avg_glucose_level = csv["avg_glucose_level"]
avg_glucose_level.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
bmi = csv["bmi"]
bmi.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
smoking_status = csv["smoking_status"]
smoking_status.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
stroke = csv["stroke"]
stroke.value_counts().plot.bar()
# Out:
# <AxesSubplot:>
